# %% [markdown]
# <a href="https://colab.research.google.com/github/vmtorresa/MetNumUN2024I/blob/main/Lab4/SymPyLab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Grupo 22
#
# #### Integrantes:
#
#
# *   (22) Jesus Andres Inguilan Paguay
# *   (42) Cristian Felipe Ramirez Montenegro
# *   (55) Victor Manuel Torres Alonso

# %% [markdown]
# # SymPyLab
#
# SymPy’s documentation
# - https://docs.sympy.org/latest/index.html

# %% [markdown]
# ## SymPy’s polynomials
# - https://docs.sympy.org/latest/modules/polys/basics.html#polynomials
#
# **Números en la lista: 22, 42, 55**
#
# $$ P_n(x) =  a_n x^n + a_{n-1} x^{n-1} + a_{n-2} x^{n-2} +\cdots +  a_1 x  + a_0$$
#
# $$P_n(x) = 0 $$
#
# $$a_n x^n + a_{n-1} x^{n-1} + a_{n-2} x^{n-2} +\cdots +  a_1 x  + a_0 = 0$$
#
# $$(x-r_1) Q_{n-1}(x) = P_n(x)$$
# $$(x-r_1) (x - r_2) Q_{n-2}(x) = P_n(x)$$
# $$ \vdots $$
#
# - (x-7)(x-9)(x-1)(x-3)(x-4)(x-8)(x-6)(x-5)(x-2)(x-2) = x^10 - 47 x^9 + 960 x^8 - 11190 x^7 + 82173 x^6 - 395871 x^5 + 1262330 x^4 - 2620060 x^3 + 3371976 x^2 - 2416032 x + 725760
#
# - (x^10 - 47 x^9 + 960 x^8 - 11190 x^7 + 82173 x^6 - 395871 x^5 + 1262330 x^4 - 2620060 x^3 + 3371976 x^2 - 2416032 x + 725760) / (x-1) = x^9 - 46 x^8 + 914 x^7 - 10276 x^6 + 71897 x^5 - 323974 x^4 + 938356 x^3 - 1681704 x^2 + 1690272 x - 725760

# %% [markdown]
# # Number of operations to compute a polynomial
# ## Extended
# $$ a_5 x^5 + a_4 x^4 + a_3 x^3 + a_2 x^2 + a_1 x + a_0 = a_5*x*x*x*x*x + a_4*x*x*x*x  + a_3*x*x*x + a_2*x*x + a_1*x + a_0$$
#
# $$ 5+4+3+2+1 = \frac{5*6}{2} (*) + 5 (+)  =20 \text{ ops} $$
#
# $$ a_n x^n + a_{n-1} x^{n-1} + a_{n-2} x^{n-2} + \cdots + a_2 x^2 + a_1 x + a_0$$
#
# $$ \frac{n(n+1)}{2} (*) + n (+)  =\frac{n^2}{2} + \frac{3}{2} n\text{ ops} $$

# %% [markdown]
# ## Monomials product
#
# $$(x-r_1)(x-r_2)(x-r_3)(x-r_4)(x-r_5)(x-r_6)(x-r_7)(x-r_8)(x-r_9)(x-r_{10})$$
#
#
# $$ 10 (-) + 9 (*) = 19  \text{ ops} $$
#
# $$(x-r_1)(x-r_2)(x-r_3)\cdots (x-r_{n-1})(x-r_n)$$
#
# $$ n-1 (*) + n (-)  =  2n-1 \text{ ops} $$

# %% [markdown]
# ## Nexted
# $$  ((((a_5 x+ a_4 )x  + a_3) x + a_2)x +a_1)x + a_0 $$
#
# $$ 5 (*) + 5 (+)  = 10 \text{ ops} $$
#
#
# $$ ((((a_n x+ a_{n-1} )x  + a_{n-1}) x + \cdots a_2)x +a_1)x + a_0 $$
#
# $$ n (*) + n (+)  = 2n \text{ ops} $$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol
from sympy import div

x = Symbol('x')

p = x**10 - 47*x**9  + 960*x**8 - 11190*x**7 + 82173*x**6 - 395871*x**5 + 1262330*x**4 - 2620060*x**3 + 3371976*x**2 - 2416032*x + 725760

p, r = div(p,  x-1)

print(p)
print(r)

p, r = div(p,  x-2)

print(p)
print(r)

p, r = div(p,  x-3)

print(p)
print(r)

p, r = div(p,  x-4)

print(p)
print(r)

p, r = div(p,  x-5)

print(p)
print(r)
# Out:
# x**9 - 46*x**8 + 914*x**7 - 10276*x**6 + 71897*x**5 - 323974*x**4 + 938356*x**3 - 1681704*x**2 + 1690272*x - 725760
# 0
# x**8 - 44*x**7 + 826*x**6 - 8624*x**5 + 54649*x**4 - 214676*x**3 + 509004*x**2 - 663696*x + 362880
# 0
# x**7 - 41*x**6 + 703*x**5 - 6515*x**4 + 35104*x**3 - 109364*x**2 + 180912*x - 120960
# 0
# x**6 - 37*x**5 + 555*x**4 - 4295*x**3 + 17924*x**2 - 37668*x + 30240
# 0
# x**5 - 32*x**4 + 395*x**3 - 2320*x**2 + 6324*x - 6048
# 0

# %%
p = x**10 - 47*x**9  + 960*x**8 - 11190*x**7 + 82173*x**6 - 395871*x**5 + 1262330*x**4 - 2620060*x**3 + 3371976*x**2 - 2416032*x + 725760

p, r = div(p,  x-11)

print(p)
print(r)
# Out:
# x**9 - 36*x**8 + 564*x**7 - 4986*x**6 + 27327*x**5 - 95274*x**4 + 214316*x**3 - 262584*x**2 + 483552*x + 2903040
# 32659200

# %% [markdown]
# ## SymPy’s polynomial simple univariate polynomial factorization
# - https://docs.sympy.org/latest/modules/polys/wester.html#simple-univariate-polynomial-factorization
# - factor(725760 - 2416032 x + 3371976 x^2 - 2620060 x^3 + 1262330 x^4 - 395871 x^5 + 82173 x^6 - 11190 x^7 + 960 x^8 - 47 x^9 + x^10)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol,factor
x = Symbol('x')
factor(x**10 - 47*x**9  + 960*x**8 - 11190*x**7 + 82173*x**6 - 395871*x**5 + 1262330*x**4 - 2620060*x**3 + 3371976*x**2 - 2416032*x + 725760)
# Out:
# (x - 9)*(x - 8)*(x - 7)*(x - 6)*(x - 5)*(x - 4)*(x - 3)*(x - 2)**2*(x - 1)

# %% [markdown]
# ## SymPy’s solvers
# - https://docs.sympy.org/latest/tutorial/solvers.html
# - 725760 - 2416032 x + 3371976 x^2 - 2620060 x^3 + 1262330 x^4 - 395871 x^5 + 82173 x^6 - 11190 x^7 + 960 x^8 - 47 x^9 + x^10 = 0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, solveset, Eq
x = Symbol('x')
solveset(Eq(x**10 - 47*x**9  + 960*x**8 - 11190*x**7 + 82173*x**6 - 395871*x**5 + 1262330*x**4 - 2620060*x**3 + 3371976*x**2 - 2416032*x + 725760, 0), x)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %% [markdown]
# (x -pi) (x- sqtr(2)) = 0
# x**2- (pi + sqtr(2))*x + (pi* sqrt(2)) =0

# %% [markdown]
# <img src="https://raw.githubusercontent.com/gjhernandezp/NM/main/SymPyLab/sympylabwolfram5.jpg" />

# %%
from sympy import Symbol, solveset, Eq, sqrt, pi, E
x = Symbol('x')
solveset(Eq(x**2 - (sqrt(2)+pi)*x + (sqrt(2)*pi) , 0), x)
# Out:
# {sqrt(2), pi}

# %% [markdown]
# *   Reference docs for the Poly Domains https://docs.sympy.org/dev/modules/polys/domainsref.html
#
# *   Introducing the Domains of the poly module https://docs.sympy.org/dev/modules/polys/domainsintro.html
#
# *   Internals of the Polynomial Manipulation Module https://docs.sympy.org/latest/modules/polys/internals.html

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol,factor
x = Symbol('x')
factor(x**10 - 47*x**9  + 960*x**8 - 11190*x**7 + 82173*x**6 - 395871*x**5 + 1262330*x**4 - 2620060*x**3 + 3371976*x**2 - 2416032*x + 725760,domain='GF(2)')
# Out:
# x**5*(x + 1)**5

# %% [markdown]
# ## SymPy’s Symbolic and Numercical Complex Evaluations
# - https://docs.sympy.org/latest/modules/evalf.html](https://)
# - x = x1 + I*x2,y = y1 + I*y2, z = z1 + I*z2, x * y * z

# %% [markdown]
# <img src="https://raw.githubusercontent.com/gjhernandezp/NM/main/SymPyLab/sympylabwolfram7.jpg" />

# %%
from sympy import symbols, I, N, pi, expand
x1, x2, y1, y2, z1, z2 = symbols("x1 x2 y1 y2 z1 z2", real=True)
x = x1 + I*x2
y = y1 + I*y2
z = z1 + I*z2

print(x*y*z)
print(expand(x*y*z))
print(expand((x*y)*z))
print(expand(x*(y*z)))
w=1/(pi + I)
print('w=',w)
w=N(w)
print('w=',w)
# Out:
# (x1 + I*x2)*(y1 + I*y2)*(z1 + I*z2)
# x1*y1*z1 + I*x1*y1*z2 + I*x1*y2*z1 - x1*y2*z2 + I*x2*y1*z1 - x2*y1*z2 - x2*y2*z1 - I*x2*y2*z2
# x1*y1*z1 + I*x1*y1*z2 + I*x1*y2*z1 - x1*y2*z2 + I*x2*y1*z1 - x2*y1*z2 - x2*y2*z1 - I*x2*y2*z2
# x1*y1*z1 + I*x1*y1*z2 + I*x1*y2*z1 - x1*y2*z2 + I*x2*y1*z1 - x2*y1*z2 - x2*y2*z1 - I*x2*y2*z2
# w= 1/(pi + I)
# w= 0.289025482222236 - 0.0919996683503752*I

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import symbols, I, N, pi, expand
n1, n2, m1, m2, s1, s2 = symbols("n1 n2 m1 m2 s1 s2", real=True)
n = 9*n1 + I*n2
m = 31*m1 + I*m2
s = 38*s1 + I*s2

print(n*m/s)
print(expand(n*m/s))
print(expand((n*m)/s))
print(expand(n*(m/s)))
a=1/(2*pi + I)
print('a=',a)
a=N(a)
print('a=',a)
# Out:
# (31*m1 + I*m2)*(9*n1 + I*n2)/(38*s1 + I*s2)
# 279*m1*n1/(38*s1 + I*s2) + 31*I*m1*n2/(38*s1 + I*s2) + 9*I*m2*n1/(38*s1 + I*s2) - m2*n2/(38*s1 + I*s2)
# 279*m1*n1/(38*s1 + I*s2) + 31*I*m1*n2/(38*s1 + I*s2) + 9*I*m2*n1/(38*s1 + I*s2) - m2*n2/(38*s1 + I*s2)
# 279*m1*n1/(38*s1 + I*s2) + 31*I*m1*n2/(38*s1 + I*s2) + 9*I*m2*n1/(38*s1 + I*s2) - m2*n2/(38*s1 + I*s2)
# a= 1/(2*pi + I)
# a= 0.155223096134648 - 0.0247045230318576*I

# %%
from sympy import symbols, I, N, pi, expand
n1, n2, m1, m2, s1, s2 = symbols("n1 n2 m1 m2 s1 s2", real=True)
n = 9*n1 + I*n2
m = 31*m1 + I*m2
s = 38*s1 + I*s2

print(n*m/s)
print(expand(n*m/s))
print(expand((n*m)/s))
print(expand(n*(m/s)))
a=1/(2*pi + I)
print('a=',a)
a=N(a)
print('a=',a)
# Out:
# (31*m1 + I*m2)*(9*n1 + I*n2)/(38*s1 + I*s2)
# 279*m1*n1/(38*s1 + I*s2) + 31*I*m1*n2/(38*s1 + I*s2) + 9*I*m2*n1/(38*s1 + I*s2) - m2*n2/(38*s1 + I*s2)
# 279*m1*n1/(38*s1 + I*s2) + 31*I*m1*n2/(38*s1 + I*s2) + 9*I*m2*n1/(38*s1 + I*s2) - m2*n2/(38*s1 + I*s2)
# 279*m1*n1/(38*s1 + I*s2) + 31*I*m1*n2/(38*s1 + I*s2) + 9*I*m2*n1/(38*s1 + I*s2) - m2*n2/(38*s1 + I*s2)
# a= 1/(2*pi + I)
# a= 0.155223096134648 - 0.0247045230318576*I

# %% [markdown]
# ## Wolfram alpha answers quastion in natural languaje
# - What is the average temperature in Bogota in September?
#
# <img src="https://raw.githubusercontent.com/gjhernandezp/NM/main/SymPyLab/sympylabwolfram8.jpg" />

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Try the same question asked in Wolfram Alpha in ChatGPT**
#
# https://chat.openai.com/auth/login
#
# and post the answer screenshoot.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## SymPy’s integrate
#
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, integrate, cos
x = Symbol('x')
integrate(x**3 * cos(x)**2, x)
# Out:
# x**4*sin(x)**2/8 + x**4*cos(x)**2/8 + x**3*sin(x)*cos(x)/2 - 3*x**2*sin(x)**2/8 + 3*x**2*cos(x)**2/8 - 3*x*sin(x)*cos(x)/4 + 3*sin(x)**2/8

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, integrate, sin
x = Symbol('x')
integrate(x**3 * cos(x)**2, (x,1,4))
# Out:
# -cos(1)**2/2 - sin(1)**2/8 + sin(1)*cos(1)/4 + 29*sin(4)*cos(4) + 211*sin(4)**2/8 + 38*cos(4)**2

# %%
from sympy import Symbol, integrate, sin, N
x = Symbol('x')
N(integrate(x**3 * cos(x)**2, (x,1,4)))
# Out:
# 45.5666653397323
